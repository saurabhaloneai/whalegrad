# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from whalegrad.engine.whalor import Whalor
from activations import Neuron, Layer, MLP

# %%
np.random.seed(1337)
random.seed(1337)

# %%
from sklearn.model_selection import train_test_split

# %%
# make up a dataset

from sklearn.datasets import make_moons, make_blobs, make_circles
# X, y = make_moons(n_samples=100, noise=0.1)
# load data
X, y = make_circles(n_samples=1000, noise=0.05, random_state=100)
X_train_orig, X_test_orig, y_train_orig, y_test_orig = train_test_split(X,y)
y = y*2 - 1 # make y be -1 or 1
# visualize in 2D
plt.figure(figsize=(5,5))
plt.scatter(X[:,0], X[:,1], c=y, s=20, cmap='jet')

# %%
# initialize a model 
model = MLP(2, [16, 16, 1]) # 2-layer neural network
print(model)
print("number of parameters", len(model.parameters()))
# Out:
# MLP of [Layer of [ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2)], Layer of [ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16)], Layer of [LinearNeuron(16)]]
# number of parameters 337

# %%
num_train, num_test = 750, 250 # number of train and test examples
num_iter = 50 # number of iterations

# %%
X,y = Whalor(X_train_orig[:num_train,:]), Whalor(X_test_orig[:num_test,:])

# %%
# loss function
def loss(batch_size=None):
    
    # inline DataLoader :)
    if batch_size is None:
        Xb, yb = X, y
    else:
        ri = np.random.permutation(X.shape[0])[:batch_size]
        Xb, yb = X[ri], y[ri]
    inputs = [list(map(Whalor, xrow)) for xrow in Xb]
    
    # forward the model to get scores
    scores = list(map(model, inputs))
    
    # svm "max-margin" loss
    losses = [(1 + -yi*scorei).relu() for yi, scorei in zip(yb, scores)]
    data_loss = sum(losses) * (1.0 / len(losses))
    # L2 regularization
    alpha = 1e-4
    reg_loss = alpha * sum((p*p for p in model.parameters()))
    total_loss = data_loss + reg_loss
    
    # also get accuracy
    accuracy = [(yi > 0) == (scorei.data > 0) for yi, scorei in zip(yb, scores)]
    return total_loss, sum(accuracy) / len(accuracy)

total_loss, acc = loss()
print(total_loss, acc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 27
#      24     accuracy = [(yi > 0) == (scorei.data > 0) for yi, scorei in zip(yb, scores)]
#      25     return total_loss, sum(accuracy) / len(accuracy)
# ---> 27 total_loss, acc = loss()
#      28 print(total_loss, acc)
#
# Cell In[9], line 10, in loss(batch_size)
#       8     ri = np.random.permutation(X.shape[0])[:batch_size]
#       9     Xb, yb = X[ri], y[ri]
# ---> 10 inputs = [list(map(Whalor, xrow)) for xrow in Xb]
#      12 # forward the model to get scores
#      13 scores = list(map(model, inputs))
#
# File ~/Desktop/whalegrad/whalegrad/engine/whalor.py:9, in Whalor.__init__(self, data, requires_grad, requires_broadcasting)
#       7 def __init__(self, data, requires_grad=False, requires_broadcasting=True):
# ----> 9   self.data = data
#      10   self.requires_grad = requires_grad
#      11   self.requires_broadcasting = requires_broadcasting
#
# File ~/Desktop/whalegrad/whalegrad/engine/whalor.py:135, in Whalor.data(self, data)
#     132 @data.setter
#     133 def data(self, data):
# --> 135   self._data = check_data(data)
#
# File ~/Desktop/whalegrad/whalegrad/engine/toolbox.py:17, in check_data(data)
#      15     raise TypeError("Whoa! Elements of data should be float or at least look like they can be turned into float. What's goin' on?")
#      16 else:
# ---> 17   raise TypeError(f"Oops! Expected data of types {supported_types}, but got {type(data)}. You're throwin' me a curveball here!")
#      18 return data
#
# TypeError: Oops! Expected data of types (<class 'int'>, <class 'float'>, <class 'list'>, <class 'numpy.ndarray'>, <class 'numpy.float64'>), but got <class 'whalegrad.engine.whalor.Whalor'>. You're throwin' me a curveball here!
